# %%
from ftn_graphing import create_nfl_scatter_plot

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_tendencies.csv', 
                        y_col = 'DVOA', x_col='MOT%', join_key='Tm',
                       show_trendline=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_tendencies.csv', 
                        y_col = 'DVOA', x_col='PACT%', join_key='Tm',
                       show_trendline=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_tendencies.csv', 
                        y_col = 'DVOA', x_col='TA%', join_key='Tm',
                       show_trendline=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_tendencies.csv', 
                        y_col = 'DVOA', x_col='CHK%', join_key='Tm',
                       show_trendline=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_tendencies.csv', 
                        y_col = 'DVOA', x_col='FRD%', join_key='Tm',
                       show_trendline=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_efficiency.csv', 
                        y_col = 'DVOA', x_col='SUC%', join_key='Tm',
                       show_trendline=True, show_r2=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_efficiency.csv', 
                        y_col = 'DVOA', x_col='EXP%', join_key='Tm',
                       show_trendline=True, show_r2=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_efficiency.csv', 
                        y_col = 'DVOA', x_col='HL%', join_key='Tm',
                       show_trendline=True, show_r2=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_efficiency.csv', 
                        y_col = 'DVOA', x_col='ACC%', join_key='Tm',
                       show_trendline=True, show_r2=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_efficiency.csv', 
                        y_col = 'DVOA', x_col='INT%', join_key='Tm',
                       show_trendline=True, show_r2=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_pressure.csv', 
                        y_col = 'DVOA', x_col='SAK%', join_key='Tm',
                       show_trendline=True, show_r2=True)

# %%
create_nfl_scatter_plot("data/offense_base.csv", 
                        secondary_csv='data/offense_pressure.csv', 
                        y_col = 'DVOA', x_col='PRES%', join_key='Tm',
                       show_trendline=True, show_r2=True)
