# %%
from ftn_graphing import create_nfl_scatter_plot

# %%
create_nfl_scatter_plot("data/qb_unfiltered.csv", 
                        "EPA/DB", 
                        "ACC%", 
                        title="How Good Was Each QB", 
                        label_col="Player",
                        x_label="EPA per dropback",
                        y_label="% of throws that were accurate"
                       )

# %%
create_nfl_scatter_plot("data/rookie_qb_unfiltered.csv", 
                        "EPA/DB", 
                        "ACC%", 
                        title="How Good Was Each QB", 
                        label_col="Player",
                        x_label="EPA per dropback",
                        y_label="Accuracy"
                       )
