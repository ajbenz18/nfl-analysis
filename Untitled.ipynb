# %%
from ftn_graphing import create_nfl_scatter_plot

# %%
create_nfl_scatter_plot("data/offense_tendancies.csv", 
                        "PACT%", 
                        "MOT%", 
                        title="Offensive Situations for QBs", 
                        label_col="Player",
                        x_label="% of Plays with Play Action",
                        y_label="% of Plays with Motion"
                       )
