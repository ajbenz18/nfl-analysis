# %%
from ftn_graphing import create_nfl_scatter_plot

# %%
create_nfl_scatter_plot("data/jj_v_kyler/qb_efficiency.csv", 
                        y_col = 'EPA/DB', x_col='ACC%', title="Accuracy vs EPA/DB", label_col='Player', x_is_percentage=True)

# %%
create_nfl_scatter_plot("data/jj_v_kyler/tendencies.csv", 
                        y_col = 'SRD%', x_col='FRD%', title='% of Throws to the First Read vs Second Read',
                        y_label="Second Read %", x_label='First Read %',
                        label_col='Player', x_is_percentage=True, y_is_percentage=True)

# %%
create_nfl_scatter_plot("data/jj_v_kyler/tendencies.csv", secondary_csv='data/jj_v_kyler/pressure.csv',
                        y_col = 'CHK%', x_col='TTT', label_col='Player', join_key='Player')

# %%
create_nfl_scatter_plot("data/jj_v_kyler/srd_efficiency.csv", 
                        y_col = 'INT%', x_col='ACOM%', label_col='Player', x_is_percentage=True, y_is_percentage=True,
                       title='Interception % and Adjusted Completion % on Throws After the 1st Read')

# %%
create_nfl_scatter_plot("data/jj_v_kyler/tendencies.csv", secondary_csv='data/jj_v_kyler/pressure.csv',
                        y_col = 'CHK%', y_col_2='SCR%', x_col='TTT', label_col='Player', join_key='Player',
                        y_is_percentage=True, x_label='Time to Throw', y_label='Checkdown + Scramble Percentage')
