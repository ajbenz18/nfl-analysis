# %%
from ftn_graphing import create_nfl_scatter_plot
create_nfl_scatter_plot("data/aj_brown/receiver_outside_efficiency.csv", secondary_csv='data/aj_brown/receiver_outside_coverage.csv',
                        x_col = 'YPRR', y_col='OPEN%', label_col='Player', join_key='Player',
                        y_is_percentage=True, x_label='Yards Per Route Run',
                        y_label='% of Routes Where Reciever Was Open',
                       title = 'Receiver Metrics (slot snaps excluded, > 35 receptions)')

# %%
create_nfl_scatter_plot("data/offensiveDVOA.csv", secondary_csv='data/defensiveDVOA.csv',
                        x_col = 'DVOA', y_col='DDVOA', label_col='Player', join_key='Tm', invert_y=True,
                        y_is_percentage=True, x_is_percentage=True, x_label='Offensive DVOA',
                        y_label='Defensive DVOA',
                       title = 'Team DVOA')
