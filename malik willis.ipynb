# %%
from ftn_graphing import create_nfl_scatter_plot

# %%
create_nfl_scatter_plot("data/qb_malik_willis.csv", 
                        "ACOM%", 
                        "HL%", 
                        title="Malik Willis Was Really Good", 
                        label_col="Player",
                        x_label="Completetion % Excluding Drops and Throwaways",
                        y_label="Highlight Throw Rate"
                       )
